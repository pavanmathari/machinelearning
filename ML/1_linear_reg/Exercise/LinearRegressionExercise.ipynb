# %%
ls
# Out:
# canada_per_capita_income.csv

# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np

# %%
ls
# Out:
# canada_per_capita_income.csv

# %%
df=pd.read_csv("canada_per_capita_income.csv")

# %%
df.head(3)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484

# %%
# %matplotlib inline
plt.scatter(df["year"], df["per capita income (US$)"], color="red", marker="+")
plt.plot(df.year, reg.predict(df[['year']]))

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['year']],df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# /Users/nani/Desktop/venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
ls
# Out:
# canada_per_capita_income.csv

# %%
plt.plot(df.year, reg.predict(df[['year']]))
